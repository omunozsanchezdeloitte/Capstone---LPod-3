# %%
import pandas as pd

df = pd.read_csv(r'zippedData\tmdb.movies.csv.gz',index_col=0)
df.sort_values('vote_average',ascending=False)
# Out:
#                    genre_ids      id original_language  \
# 13258                   [99]  403294                en
# 22787               [27, 35]  444170                en
# 22592                   [99]  488357                en
# 22607                     []  437448                en
# 22610  [9648, 37, 18, 10402]  463601                en
# ...                      ...     ...               ...
# 11018                     []  124727                en
# 14168                     []  167531                en
# 14167            [99, 10402]  221918                en
# 20601               [18, 35]  448105                en
# 26516               [53, 27]  309885                en
#
#                                           original_title  popularity  \
# 13258                                  9/11: Simulations       0.600
# 22787         Lasagna Cat - Telephone Sex Survey Results       0.722
# 22592                                  MOTO 9: The Movie       0.900
# ...

# %%
import sqlite3
conn = sqlite3.connect('zippedData/im.db')

# %%
pd.read_sql('''
                SELECT name
                FROM sqlite_schema
                WHERE type = 'table'
                ORDER BY name
;''',conn)
# Out:
#             name
# 0      directors
# 1      known_for
# 2     movie_akas
# 3   movie_basics
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
q = '''SELECT *
    FROM movie_ratings

;'''

im_db_movie_ratings = pd.read_sql(q,conn)
im_db_movie_ratings.sort_values('averagerating',ascending=False)
im_db_movie_ratings.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
q = '''SELECT *
    FROM movie_basics

;'''

im_db_movie_basics = pd.read_sql(q,conn)
im_db_movie_basics['genres'][1].split(',')
# Out:
# ['Biography', 'Drama']

# %%
q = '''SELECT *
    FROM movie_basics AS mb
    JOIN movie_ratings as mr
        USING ('movie_id')
    
   
;'''

df = pd.read_sql(q,conn)
df.head()
df.hist('averagerating',bins=20);
df.shape
# Out:
# (73856, 8)

# %%
import matplotlib.pyplot as plt

# %%
q = '''SELECT genres,AVG(averagerating) AS AVG_Rating
    FROM movie_basics AS mb
    JOIN movie_ratings as mr
        USING ('movie_id')
    WHERE numvotes > 3400
    GROUP BY genres
    HAVING AVG_Rating > 8
    ORDER BY AVG_Rating DESC
;'''

df = pd.read_sql(q,conn)
df
# Out:
#                             genres  AVG_Rating
# 0                        Biography       8.600
# 1              Drama,Romance,Sport       8.500
# 2        Documentary,History,Music       8.300
# 3               Documentary,Family       8.300
# 4                Animation,History       8.300
# 5      Adventure,Documentary,Sport       8.300
# 6             Drama,Family,Musical       8.200
# 7            Comedy,Drama,Thriller       8.200
# 8      Biography,Documentary,Drama       8.200
# 9        Documentary,Drama,History       8.100
# 10  Biography,Documentary,Thriller       8.100
# 11      Biography,Documentary,News       8.100
# 12               Documentary,Sport       8.025

# %%
q = '''SELECT genres,averagerating 
    FROM movie_basics AS mb
    JOIN movie_ratings as mr
        USING ('movie_id')
    WHERE numvotes > 3400
    
;'''

df = pd.read_sql(q,conn)
def split(string):
    return string.split()

df['genres'] = df['genres'].apply(split)
df
# Out:
#                            genres  averagerating
# 0      [Action,Adventure,Fantasy]            4.2
# 1                        [Comedy]            5.1
# 2     [Adventure,Animation,Drama]            7.0
# 3         [Biography,Drama,Sport]            7.6
# 4         [Drama,Fantasy,Romance]            6.5
# ...                           ...            ...
# 4867               [Comedy,Drama]            7.2
# 4868        [Crime,Drama,Mystery]            8.1
# 4869              [Drama,Romance]            6.6
# 4870        [Documentary,History]            4.7
# 4871            [Biography,Drama]            3.7
#
# [4872 rows x 2 columns]

# %%
def asd(df):
    new_df = pd.DataFrame({},columns=['genres','averagerating'])
    for indx in df.index:
        new = pd.DataFrame({'genres':[df.iloc[indx,0],df.iloc[indx,1]]},index=list(range(len(df.iloc[indx,0])+1)))
        pd.concat([new_df,new],ignore_index=True)
           
    
    return new_df

# %%
asd(df)
# Out:
# Empty DataFrame
# Columns: [genres, averagerating]
# Index: []

# %%
a=pd.DataFrame({},columns=['genres','averagerating'])
b=pd.DataFrame({'genres':['ave','romance'],'averagerating':4.5},index=list(range(0,2)))

pd.concat([a,b])
# Out:
#     genres  averagerating
# 0      ave            4.5
# 1  romance            4.5

# %%
list(range(len(df.iloc[1,0])))
# Out:
# [0]

# %%
max(df['averagerating'])
# Out:
# 10.0

# %%
df.value_counts('movie_id').unique()
# Out:
# array([1], dtype=int64)

# %%
q = '''SELECT *
    FROM movie_akas
    LEFT JOIN movie_ratings
        USING(movie_id)
   
;'''

df = pd.read_sql(q,conn)
df
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
# ...
