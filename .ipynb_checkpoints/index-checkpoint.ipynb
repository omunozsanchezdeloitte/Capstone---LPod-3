# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
import sqlite3
conn = sqlite3.connect('zippedData/im.db')

# %%
q = '''SELECT *
    FROM movie_basics AS mb
    JOIN movie_ratings as mr
        USING ('movie_id')
    
   ;'''

movie_basics_ratings = pd.read_sql(q,conn)
movie_basics_ratings
# Out:
#         movie_id                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes                genres  averagerating  \
# 0            2013            175.0    Action,Crime,Drama            7.0
# 1            2019            114.0       Biography,Drama            7.2
# 2            2018            122.0                 Drama            6.9
# 3            2018              NaN          Comedy,Drama            6.1
# 4            2017             80.0  Comedy,Drama,Fantasy            6.5
# ...           ...              ...                   ...            ...
# 73851        2019             75.0           Documentary            6.2
# 73852        2019             98.0          Drama,Family            8.7
# 73853        2017              NaN           Documentary            8.5
# 73854        2019              NaN                  None            6.6
# 73855        2019             72.0           Documentary            6.5
#
#        numvotes
# 0            77
# 1            43
# 2          4517
# 3            13
# 4           119
# ...         ...
# 73851         6
# 73852       136
# 73853         8
# 73854         5
# 73855        11
#
# [73856 rows x 8 columns]

# %%
movie_basics_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         73856 non-null  object
#  1   primary_title    73856 non-null  object
#  2   original_title   73856 non-null  object
#  3   start_year       73856 non-null  int64
#  4   runtime_minutes  66236 non-null  float64
#  5   genres           73052 non-null  object
#  6   averagerating    73856 non-null  float64
#  7   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.5+ MB

# %%
movie_basics_ratings.isna().sum()
# Out:
# movie_id              0
# primary_title         0
# original_title        0
# start_year            0
# runtime_minutes    7620
# genres              804
# averagerating         0
# numvotes              0
# dtype: int64

# %%
movie_basics_ratings.dropna(subset=['genres'], inplace=True)
movie_basics_ratings
# Out:
#         movie_id                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73850  tt9913056                     Swarm Season                Swarm Season
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes                genres  averagerating  \
# 0            2013            175.0    Action,Crime,Drama            7.0
# 1            2019            114.0       Biography,Drama            7.2
# 2            2018            122.0                 Drama            6.9
# 3            2018              NaN          Comedy,Drama            6.1
# 4            2017             80.0  Comedy,Drama,Fantasy            6.5
# ...           ...              ...                   ...            ...
# 73850        2019             86.0           Documentary            6.2
# 73851        2019             75.0           Documentary            6.2
# 73852        2019             98.0          Drama,Family            8.7
# 73853        2017              NaN           Documentary            8.5
# 73855        2019             72.0           Documentary            6.5
#
#        numvotes
# 0            77
# 1            43
# 2          4517
# 3            13
# 4           119
# ...         ...
# 73850         5
# 73851         6
# 73852       136
# 73853         8
# 73855        11
#
# [73052 rows x 8 columns]

# %%
movie_basics_ratings['numvotes'].mean()
# Out:
# 3562.1726304550184

# %%
condition = movie_basics_ratings['numvotes'] > 3500
movie_basics_ratings = movie_basics_ratings[condition]
movie_basics_ratings.reset_index(inplace=True)
movie_basics_ratings
# Out:
#       index   movie_id                    primary_title  \
# 0         2  tt0069049       The Other Side of the Wind
# 1        16  tt0249516                       Foodfight!
# 2        31  tt0315642                            Wazir
# 3        41  tt0337692                      On the Road
# 4        47  tt0359950  The Secret Life of Walter Mitty
# ...     ...        ...                              ...
# 4769  73133  tt9364684                        Borç Harç
# 4770  73206  tt9412098                             Fyre
# 4771  73304  tt9495224       Black Mirror: Bandersnatch
# 4772  73374  tt9558612                 PM Narendra Modi
# 4773  73388  tt9573980                Leaving Neverland
#
#                        original_title  start_year  runtime_minutes  \
# 0          The Other Side of the Wind        2018            122.0
# 1                          Foodfight!        2012             91.0
# 2                               Wazir        2016            103.0
# 3                         On the Road        2012            124.0
# 4     The Secret Life of Walter Mitty        2013            114.0
# ...                               ...         ...              ...
# 4769                        Borç Harç        2019             90.0
# 4770                             Fyre        2019             97.0
# 4771       Black Mirror: Bandersnatch        2018             90.0
# 4772                 PM Narendra Modi        2019            136.0
# 4773                Leaving Neverland        2019            240.0
#
#                        genres  averagerating  numvotes
# 0                       Drama            6.9      4517
# 1     Action,Animation,Comedy            1.9      8248
# 2          Action,Crime,Drama            7.1     15378
# 3     Adventure,Drama,Romance            6.1     37886
# 4      Adventure,Comedy,Drama            7.3    275300
# ...                       ...            ...       ...
# 4769                   Comedy            1.4      3511
# 4770        Documentary,Music            7.3     25387
# 4771     Drama,Mystery,Sci-Fi            7.3     91349
# 4772          Biography,Drama            3.7      4057
# 4773              Documentary            7.1     19632
#
# [4774 rows x 9 columns]

# %%
genres_rating = movie_basics_ratings[['genres','averagerating']]
genres_rating
# Out:
#                        genres  averagerating
# 0                       Drama            6.9
# 1     Action,Animation,Comedy            1.9
# 2          Action,Crime,Drama            7.1
# 3     Adventure,Drama,Romance            6.1
# 4      Adventure,Comedy,Drama            7.3
# ...                       ...            ...
# 4769                   Comedy            1.4
# 4770        Documentary,Music            7.3
# 4771     Drama,Mystery,Sci-Fi            7.3
# 4772          Biography,Drama            3.7
# 4773              Documentary            7.1
#
# [4774 rows x 2 columns]

# %%
def split(string):
    return string.split(',')

genres_rating['genres'] = genres_rating['genres'].apply(split)
genres_rating
# Out:
# <ipython-input-85-7e01c58eccd2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genres_rating['genres'] = genres_rating['genres'].apply(split)
#                            genres  averagerating
# 0                         [Drama]            6.9
# 1     [Action, Animation, Comedy]            1.9
# 2          [Action, Crime, Drama]            7.1
# 3     [Adventure, Drama, Romance]            6.1
# 4      [Adventure, Comedy, Drama]            7.3
# ...                           ...            ...
# 4769                     [Comedy]            1.4
# 4770         [Documentary, Music]            7.3
# 4771     [Drama, Mystery, Sci-Fi]            7.3
# 4772           [Biography, Drama]            3.7
# 4773                [Documentary]            7.1
#
# [4774 rows x 2 columns]

# %%
def split_genres(df):
    new_df = pd.DataFrame({},columns=['genres','averagerating'])
    for indx in df.index:
        new = pd.DataFrame({'genres':df.iloc[indx,0],'averagerating':df.iloc[indx,1]})
        new_df = pd.concat([new_df,new],ignore_index=True)
           
    
    return new_df

# %%
genres_rating = split_genres(genres_rating)

# %%
genre_rate = genres_rating.groupby('genres')[['averagerating']].mean().sort_values('averagerating',ascending=False)
genre_rate.index
# Out:
# Index(['News', 'Documentary', 'Biography', 'Sport', 'History', 'War',
#        'Musical', 'Music', 'Animation', 'Drama', 'Western', 'Crime', 'Romance',
#        'Adventure', 'Family', 'Comedy', 'Action', 'Mystery', 'Thriller',
#        'Fantasy', 'Sci-Fi', 'Horror'],
#       dtype='object', name='genres')

# %%
#sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
sns.set_theme()
sns.set_context("talk")
fig,ax =plt.subplots(figsize=(13,8))
genre_rate.plot(kind='bar',ax=ax,rot=60)
ax.set_ylabel('Rating')
ax.legend();

# %%
q = '''SELECT *
    FROM movie_basics AS mb
    JOIN movie_ratings as mr
        USING ('movie_id')
    WHERE numvotes > 3400
    
;'''

df = pd.read_sql(q,conn)
df1=df.groupby('genres')[['averagerating']].mean().sort_values('averagerating',ascending=False)
df1['count'] = df.groupby('genres')[['averagerating']].count()
df1
# Out:
#                              averagerating  count
# genres
# Biography                              8.6      1
# Drama,Romance,Sport                    8.5      1
# Documentary,Family                     8.3      1
# Animation,History                      8.3      1
# Adventure,Documentary,Sport            8.3      1
# ...                                    ...    ...
# Action,Adventure,History               4.5      1
# Crime,Romance,Thriller                 4.3      1
# Comedy,Romance,Sci-Fi                  4.2      1
# Comedy,Family,Sci-Fi                   2.6      1
# Crime,Mystery                          1.5      1
#
# [387 rows x 2 columns]
