# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats 
import sqlite3
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
budgets = pd.read_csv(r'zippedData\tn.movie_budgets.csv.gz')
budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
#we change the dtype of the date to a datetime so we can split the year and month of each movie

budgets["release_date"] = pd.to_datetime(budgets["release_date"])

# %%
#we create a column named month and year so we can save that in the dataframe
budgets['month'] = budgets["release_date"].dt.month_name()

budgets['year'] = budgets["release_date"].dt.year
budgets
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       Red 11
# 5778  79   1999-04-02                                    Following
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross      month  year
# 0         $425,000,000   $760,507,625  $2,776,345,279   December  2009
# 1         $410,600,000   $241,063,875  $1,045,663,875        May  2011
# 2         $350,000,000    $42,762,350    $149,762,350       June  2019
# 3         $330,600,000   $459,005,868  $1,403,013,963        May  2015
# 4         $317,000,000   $620,181,382  $1,316,721,747   December  2017
# ...                ...            ...             ...        ...   ...
# 5777            $7,000             $0              $0   December  2018
# 5778            $6,000        $48,482        $240,495      April  1999
# 5779            $5,000         $1,338          $1,338       July  2005
# 5780            $1,400             $0              $0  September  2015
# 5781            $1,100       $181,041        $181,041     August  2005
#
# [5782 rows x 8 columns]

# %%
#we clean the worlwide gross and production budget columns so we can sum the values

budgets['worldwide_gross'] = budgets.worldwide_gross.apply(lambda x:x.replace('$','').replace(',',''))
budgets['worldwide_gross'] = budgets['worldwide_gross'].astype(float)

budgets['production_budget'] = budgets.production_budget.apply(lambda x:x.replace('$','').replace(',',''))
budgets['production_budget'] = budgets['production_budget'].astype(float)

# %%
#we add a season column so we can also filter the data by season if its neccesary

season_dict = {'January': 'Winter',
               'February': 'Winter',
               'March': 'Spring', 
               'April': 'Spring',
               'May': 'Spring',
               'June': 'Summer',
               'July': 'Summer',
               'August': 'Summer',
               'September': 'Fall',
               'October': 'Fall',
               'November': 'Fall',
               'December': 'Winter'}
budgets['Season'] = budgets['month'].apply(lambda x: season_dict[x])

# %%
# we filter the data to get relevant information
recent_movies =  budgets.query("year >= 2012").iloc[:1400]
recent_movies
# Out:
#       id release_date                                 movie  \
# 2      3   2019-06-07                          Dark Phoenix
# 3      4   2015-05-01               Avengers: Age of Ultron
# 4      5   2017-12-15     Star Wars Ep. VIII: The Last Jedi
# 5      6   2015-12-18  Star Wars Ep. VII: The Force Awakens
# 6      7   2018-04-27                Avengers: Infinity War
# ...   ..          ...                                   ...
# 5044  45   2015-12-18                              Saul fia
# 5047  48   2019-02-01                                 Braid
# 5059  60   2014-09-26                       Two Night Stand
# 5063  64   2016-10-21                             Moonlight
# 5069  70   2018-03-23                                Unsane
#
#       production_budget domestic_gross  worldwide_gross      month  year  \
# 2           350000000.0    $42,762,350     1.497624e+08       June  2019
# 3           330600000.0   $459,005,868     1.403014e+09        May  2015
# 4           317000000.0   $620,181,382     1.316722e+09   December  2017
# 5           306000000.0   $936,662,225     2.053311e+09   December  2015
# 6           300000000.0   $678,815,482     2.048134e+09      April  2018
# ...                 ...            ...              ...        ...   ...
# 5044          1700000.0     $1,777,043     9.696537e+06   December  2015
# 5047          1660000.0             $0     8.074500e+04   February  2019
# 5059          1600000.0        $15,600     8.680810e+05  September  2014
# 5063          1500000.0    $27,854,931     6.524551e+07    October  2016
# 5069          1500000.0     $7,690,044     1.424493e+07      March  2018
#
#       Season
# 2     Summer
# 3     Spring
# 4     Winter
# 5     Winter
# 6     Spring
# ...      ...
# 5044  Winter
# 5047  Winter
# 5059    Fall
# 5063    Fall
# 5069  Spring
#
# [1400 rows x 9 columns]

# %%
recent_movies.describe()
# Out:
#                 id  production_budget  worldwide_gross         year
# count  1400.000000       1.400000e+03     1.400000e+03  1400.000000
# mean     50.713571       4.420323e+07     1.400171e+08  2015.025714
# std      28.496744       5.513857e+07     2.413918e+08     2.057965
# min       1.000000       1.500000e+06     0.000000e+00  2012.000000
# 25%      27.000000       9.000000e+06     7.412207e+06  2013.000000
# 50%      50.500000       2.200000e+07     4.633515e+07  2015.000000
# 75%      75.000000       5.500000e+07     1.531550e+08  2017.000000
# max     100.000000       3.500000e+08     2.053311e+09  2020.000000

# %%
population = recent_movies['worldwide_gross']

sns.histplot(population, kde=True);

# %%
condition_on_season = recent_movies['Season'] == 'Summer'

sample = recent_movies[condition_on_season][['worldwide_gross']]
print(sample.mean())
sample
# Out:
# worldwide_gross    1.744930e+08
# dtype: float64
#       worldwide_gross
# 2        1.497624e+08
# 10       1.084439e+09
# 12       2.600021e+08
# 28       6.679995e+08
# 30       7.578903e+08
# ...               ...
# 4990     0.000000e+00
# 4997     0.000000e+00
# 4999     0.000000e+00
# 5012     2.855930e+05
# 5017     2.326513e+07
#
# [314 rows x 1 columns]

# %%
sns.histplot(sample, kde=True);

# %% [markdown]
# ### Steps for performing hypothesis testing
#
#
# 1. **$H_o$** = Population mean (1.400171e+08) and sample mean (1.744930e+08) are the same
#
#    **$H_a$** = Population mean (1.400171e+08) and sample mean (1.744930e+08) are not the same
#
#
# 2. We choose a statistical significance of $\alpha$ = 0.05
#
#
# 3. Steps $3$, $4$ and $5$ can be avoided using built-in scipy `ttest_1samp()` function

# %%
results = stats.ttest_1samp(
    a=sample,   # the entire array-like sample
    popmean=1.400171e+08 # the mean you are testing the sample against
)

results
# Out:
# Ttest_1sampResult(statistic=array([2.335061]), pvalue=array([0.02017201]))

# %%
resolution = results[1][0]/2 < 0.05

if resolution == True:
    print(f'With a p-value of {results[1][0]/2}, we are able to reject the Null Hypothesis,\
    meaning that the average runtime of Documentaries is less than that of the population,\
          with an statistical significance of 5%')
else:
    print(f'With a p-value of {results[1][0]/2}, we are unable to reject the Null Hypothesis')
# Out:
# With a p-value of 0.010086005398796699, we are able to reject the Null Hypothesis,    meaning that the average runtime of Documentaries is less than that of the population,          with an statistical significance of 5%
